# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('omicron.csv')
data.head()
# Out:
#      Country        Date  Percentage of Omicron
# 0     Angola   9/20/2021                    0.0
# 1     Angola   10/4/2021                    0.0
# 2  Argentina   9/20/2021                    0.0
# 3  Argentina   10/4/2021                    0.0
# 4  Argentina  10/18/2021                    0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552 entries, 0 to 551
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                552 non-null    object
#  1   Date                   552 non-null    object
#  2   Percentage of Omicron  552 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 13.1+ KB

# %%
data['Date'].unique()
# Out:
# array(['9/20/2021', '10/4/2021', '10/18/2021', '11/1/2021', '11/15/2021',
#        '11/29/2021', '12/13/2021', '12/27/2021', '1/5/2022'], dtype=object)

# %%
begin_date = '9/20/2021'
data[data['Date']==begin_date]
# Out:
#             Country       Date  Percentage of Omicron
# 0            Angola  9/20/2021                    0.0
# 2         Argentina  9/20/2021                    0.0
# 10            Aruba  9/20/2021                    0.0
# 16        Australia  9/20/2021                    0.0
# 24          Austria  9/20/2021                    0.0
# ..              ...        ...                    ...
# 514          Turkey  9/20/2021                    0.0
# 522         Ukraine  9/20/2021                    0.0
# 525  United Kingdom  9/20/2021                    0.0
# 534   United States  9/20/2021                    0.0
# 543         Vietnam  9/20/2021                    0.0
#
# [73 rows x 3 columns]

# %%
latest_date = '1/5/2022'
data[data['Date']==latest_date]
# Out:
#             Country      Date  Percentage of Omicron
# 50          Belgium  1/5/2022                  50.85
# 181          France  1/5/2022                  80.34
# 388          Poland  1/5/2022                  11.29
# 533  United Kingdom  1/5/2022                  95.91
# 542   United States  1/5/2022                  80.00

# %%
negara1 = data[data['Country'] == 'Indonesia']
negara1
# Out:
#        Country        Date  Percentage of Omicron
# 223  Indonesia   9/20/2021                   0.00
# 224  Indonesia   10/4/2021                   0.00
# 225  Indonesia  10/18/2021                   0.00
# 226  Indonesia   11/1/2021                   0.00
# 227  Indonesia  11/15/2021                   0.00
# 228  Indonesia  11/29/2021                   0.00
# 229  Indonesia  12/13/2021                   1.00
# 230  Indonesia  12/27/2021                  41.56

# %%
negaramalay = data[data['Country'] == 'Malaysia']
negaramalay
# Out:
#       Country        Date  Percentage of Omicron
# 300  Malaysia   9/20/2021                   0.00
# 301  Malaysia   10/4/2021                   0.00
# 302  Malaysia  10/18/2021                   0.00
# 303  Malaysia   11/1/2021                   0.00
# 304  Malaysia  11/15/2021                   0.00
# 305  Malaysia  11/29/2021                   0.33
# 306  Malaysia  12/13/2021                   5.05
# 307  Malaysia  12/27/2021                  11.90

# %%
negaraind = negara1[negara1['Percentage of Omicron']>0]
negaraind
# Out:
#        Country        Date  Percentage of Omicron
# 229  Indonesia  12/13/2021                   1.00
# 230  Indonesia  12/27/2021                  41.56

# %%
negaraind['Date'] = pd.to_datetime(negaraind['Date'])
negaramalay['Date'] = pd.to_datetime(negaramalay['Date'])
negaraind.head()
# Out:
# C:\Users\abdul\AppData\Local\Temp/ipykernel_4852/1087309357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negaraind['Date'] = pd.to_datetime(negaraind['Date'])
# C:\Users\abdul\AppData\Local\Temp/ipykernel_4852/1087309357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negaramalay['Date'] = pd.to_datetime(negaramalay['Date'])
#        Country       Date  Percentage of Omicron
# 229  Indonesia 2021-12-13                   1.00
# 230  Indonesia 2021-12-27                  41.56

# %%
negaraind['BaseDate'] = pd.to_datetime('2021-12-13')
negaramalay['BaseDate'] = pd.to_datetime('2021-09-20')
negaraind.head()
# Out:
# C:\Users\abdul\AppData\Local\Temp/ipykernel_4852/3836512751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negaraind['BaseDate'] = pd.to_datetime('2021-12-13')
# C:\Users\abdul\AppData\Local\Temp/ipykernel_4852/3836512751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negaramalay['BaseDate'] = pd.to_datetime('2021-09-20')
#        Country       Date  Percentage of Omicron   BaseDate
# 229  Indonesia 2021-12-13                   1.00 2021-12-13
# ...

# %%
negaramalay.head()
# Out:
#       Country       Date  Percentage of Omicron   BaseDate
# 300  Malaysia 2021-09-20                    0.0 2021-09-20
# 301  Malaysia 2021-10-04                    0.0 2021-09-20
# 302  Malaysia 2021-10-18                    0.0 2021-09-20
# 303  Malaysia 2021-11-01                    0.0 2021-09-20
# 304  Malaysia 2021-11-15                    0.0 2021-09-20

# %%
negaraind['HariKe'] = negaraind['Date'] - negaraind['BaseDate']
negaramalay['HariKe'] = negaramalay['Date'] - negaramalay['BaseDate']
negaraind.head()
# Out:
# C:\Users\abdul\AppData\Local\Temp/ipykernel_4852/3410479397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negaraind['HariKe'] = negaraind['Date'] - negaraind['BaseDate']
# C:\Users\abdul\AppData\Local\Temp/ipykernel_4852/3410479397.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   negaramalay['HariKe'] = negaramalay['Date'] - negaramalay['BaseDate']
#        Country       Date  Percentage of Omicron   BaseDate  HariKe
# ...

# %%
negaraind.HariKe = negaraind.HariKe/pd.Timedelta(1, unit='d')
# Out:
# c:\python\python38\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
negaraind.head()
# Out:
#        Country       Date  Percentage of Omicron   BaseDate  HariKe
# 229  Indonesia 2021-12-13                   1.00 2021-12-13     0.0
# 230  Indonesia 2021-12-27                  41.56 2021-12-13    14.0

# %%
negaramalay.HariKe = negaramalay.HariKe/pd.Timedelta(1, unit='d')
negaramalay.head()
# Out:
# c:\python\python38\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#       Country       Date  Percentage of Omicron   BaseDate  HariKe
# 300  Malaysia 2021-09-20                    0.0 2021-09-20     0.0
# 301  Malaysia 2021-10-04                    0.0 2021-09-20    14.0
# 302  Malaysia 2021-10-18                    0.0 2021-09-20    28.0
# 303  Malaysia 2021-11-01                    0.0 2021-09-20    42.0
# 304  Malaysia 2021-11-15                    0.0 2021-09-20    56.0

# %%
plt.plot(negaraind.HariKe, negaraind['Percentage of Omicron'])
plt.plot(negaramalay.HariKe, negaramalay['Percentage of Omicron'])
plt.xlabel('Hari ke-')
plt.ylabel('Jumlah Kasus')
plt.legend(['Indonesia', 'Malaysia'])
plt.title('Jumlah perbandingan kasus')
plt.show()
